# %%
import numpy as np
import fit_resonator.resonator as scres

# %%
# NOTE: lmfit and inflect modules produced errors on initial run and had to be installed to conda.
# Might just be anaconda not using the locally installed modules

my_resonator = scres.Resonator(filepath='./schematic 1.s2p', measurement="S21")

# Assign your desired fit method variables
# Using the example from the README to be tweaked later
fit_type = 'DCM'
MC_iteration = 10
MC_rounds = 1e3
#Unfix w1
MC_fix = []
manual_init = None

# Pass these to your resonator object
my_resonator.fit_method(fit_type, MC_iteration, MC_rounds=MC_rounds, MC_fix=MC_fix, manual_init=manual_init,
                 MC_step_const=0.3)

my_resonator.fit()
# Out:
# preprocess_method: linear
# fscale: 1e+09
# C:\Users\Scott\anaconda3\lib\site-packages\lmfit\confidence.py:317: UserWarning: Bound reached with prob(Q=4.240495741921137) = 0.0 < max(sigmas)
#   warn(errmsg)
# C:\Users\Scott\anaconda3\lib\site-packages\lmfit\confidence.py:330: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(Q=6.086072098115176) = 0.0 < max(sigmas)
#   warn(errmsg)
# C:\Users\Scott\anaconda3\lib\site-packages\lmfit\confidence.py:330: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(Qc=4.237783245977766) = 0.0 < max(sigmas)
#   warn(errmsg)
# C:\Users\Scott\anaconda3\lib\site-packages\lmfit\confidence.py:317: UserWarning: Bound reached with prob(Qc=4.9820596339852345) = 0.0 < max(sigmas)
#   warn(errmsg)
# C:\Users\Scott\anaconda3\lib\site-packages\lmfit\confidence.py:330: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(w1=1.4318673119295074e-08) = 0.0 < max(sigmas)
#   warn(errmsg)
# C:\Users\Scott\anaconda3\lib\site-packages\lmfit\confidence.py:330: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(w1=1.561794009320311e-08) = 0.0 < max(sigmas)
#   warn(errmsg)
# C:\Users\Scott\anaconda3\lib\site-packages\lmfit\confidence.py:330: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(phi=-2.202684733723256) = 0.0 < max(sigmas)
#   warn(errmsg)
# C:\Users\Scott\anaconda3\lib\site-packages\lmfit\confidence.py:330: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(phi=-1.8663358713259823) = 0.0 < max(sigmas)
#   warn(errmsg)
# C:\Users\Scott\Documents\DLA\scresonators\fit_resonator\Sdata.py:1434: RuntimeWarning: divide by zero encountered in double_scalars
#   Qi_neg = Qi - ((ci['Q'][0][1]) ** -1 - np.real(ci['Qc'][2][1] ** -1 * np.exp(1j * fit_params[3]))) ** -1
# C:\Users\Scott\Documents\DLA\scresonators\fit_resonator\Sdata.py:1435: RuntimeWarning: divide by zero encountered in double_scalars
#   Qi_pos = Qi - ((ci['Q'][2][1]) ** -1 - np.real(ci['Qc'][0][1] ** -1 * np.exp(1j * fit_params[3]))) ** -1
# C:\Users\Scott\Documents\DLA\scresonators\fit_resonator\Sdata.py:1444: RuntimeWarning: divide by zero encountered in double_scalars
#   Qc_Re_neg = 1 / np.real(np.exp(1j * fit_params[3]) / ci['Qc'][0][1])
# C:\Users\Scott\Documents\DLA\scresonators\fit_resonator\Sdata.py:1445: RuntimeWarning: divide by zero encountered in double_scalars
#   Qc_Re_pos = 1 / np.real(np.exp(1j * fit_params[3]) / ci['Qc'][2][1])
# C:\Users\Scott\anaconda3\lib\site-packages\lmfit\confidence.py:330: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(Q=9.155404606331672) = 0.0 < max(sigmas)
#   warn(errmsg)
# C:\Users\Scott\anaconda3\lib\site-packages\lmfit\confidence.py:330: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(Q=12.892012062201573) = 0.0 < max(sigmas)
#   warn(errmsg)
# C:\Users\Scott\anaconda3\lib\site-packages\lmfit\confidence.py:330: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(Qc=30.306748023483223) = 0.0 < max(sigmas)
#   warn(errmsg)
# C:\Users\Scott\anaconda3\lib\site-packages\lmfit\confidence.py:330: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(Qc=41.5007274224059) = 0.0 < max(sigmas)
#   warn(errmsg)
# Monte Carlo fit got better fitting parameters
# Monte Carlo fit got better fitting parameters
# C:\Users\Scott\anaconda3\lib\site-packages\lmfit\confidence.py:330: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(phi=3.8246392647667227) = 0.0 < max(sigmas)
#   warn(errmsg)
# C:\Users\Scott\anaconda3\lib\site-packages\lmfit\confidence.py:330: UserWarning: rel_change=0.0 < 1e-05 at iteration 1 and prob(phi=4.132674065254954) = 0.0 < max(sigmas)
#   warn(errmsg)
# Warning: 1/Real[1/Qc] is less than 0. Calculating Qi anyway
